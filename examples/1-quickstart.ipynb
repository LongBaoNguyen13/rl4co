# %% [markdown]
# # RL4CO Quickstart Notebook
#
# <a href="https://colab.research.google.com/github/ai4co/rl4co/blob/main/examples/1-quickstart.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
# [**Documentation**](https://rl4co.readthedocs.io/) |  [**Getting Started**](https://github.com/ai4co/rl4co/tree/main#getting-started) | [**Usage**](https://github.com/ai4co/rl4co/tree/main#usage) | [**Contributing**](#contributing) | [**Paper**](https://arxiv.org/abs/2306.17100) | [**Citation**](#cite-us)

# %% [markdown]
# In this notebook we will train the AttentionModel (AM) on the TSP environment for 20 nodes. On a GPU, this should less than 2 minutes!  🚀

# %% [markdown]
# ![Alt text](https://user-images.githubusercontent.com/48984123/245925317-0db4efdd-1c93-4991-8f09-f3c6c1f35d60.png)

# %% [markdown]
# ### Installation

# %%
# Uncomment the following line to install the package from PyPI
# You may need to restart the runtime in Colab after this
# Remember to choose a GPU runtime for faster training!

# !pip install rl4co
# Out:
# Collecting rl4co
#   Downloading rl4co-0.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from rl4co) (0.8.0)
# Collecting hydra-core (from rl4co)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting hydra-colorlog (from rl4co)
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# Collecting lightning>=2.1.0 (from rl4co)
#   Downloading lightning-2.4.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from rl4co) (3.7.1)
# Collecting omegaconf (from rl4co)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyrootutils (from rl4co)
#   Downloading pyrootutils-1.0.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from rl4co) (13.7.1)
# Collecting robust-downloader (from rl4co)
#   Downloading robust_downloader-0.0.2-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rl4co) (1.13.1)
# Collecting tensordict>=0.2.0 (from rl4co)
#   Downloading tensordict-0.5.0-cp310-cp310-manylinux1_x86_64.whl.metadata (22 kB)
# Collecting torchrl>=0.2.0 (from rl4co)
#   Downloading torchrl-0.5.0-cp310-cp310-manylinux1_x86_64.whl.metadata (33 kB)
# Collecting wandb (from rl4co)
#   Downloading wandb-0.17.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.1.0->rl4co) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (2024.6.1)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.1.0->rl4co)
#   Downloading lightning_utilities-0.11.6-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.1.0->rl4co) (24.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.1.0->rl4co) (2.3.1+cu121)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning>=2.1.0->rl4co)
#   Downloading torchmetrics-1.4.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.1.0->rl4co) (4.66.5)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.1.0->rl4co) (4.12.2)
# Collecting pytorch-lightning (from lightning>=2.1.0->rl4co)
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting torch<4.0,>=2.1.0 (from lightning>=2.1.0->rl4co)
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensordict>=0.2.0->rl4co) (1.26.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from tensordict>=0.2.0->rl4co) (2.2.1)
# Collecting orjson (from tensordict>=0.2.0->rl4co)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 754.3 kB/s eta 0:00:00
# Collecting colorlog (from hydra-colorlog->rl4co)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core->rl4co)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rl4co) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rl4co) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rl4co) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rl4co) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rl4co) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rl4co) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->rl4co) (2.8.2)
# Collecting python-dotenv>=0.20.0 (from pyrootutils->rl4co)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl4co) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl4co) (2.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from robust-downloader->rl4co) (2.32.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->rl4co) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb->rl4co)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->rl4co)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->rl4co) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->rl4co) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->rl4co) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb->rl4co)
#   Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle (from wandb->rl4co)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->rl4co) (71.0.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->rl4co) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (3.10.3)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->rl4co)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->rl4co) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->robust-downloader->rl4co) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->robust-downloader->rl4co) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->robust-downloader->rl4co) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->robust-downloader->rl4co) (2024.7.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.1.0->rl4co) (4.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->rl4co)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<4.0,>=2.1.0->lightning>=2.1.0->rl4co) (1.3.0)
# Downloading rl4co-0.4.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.7/243.7 kB 12.9 MB/s eta 0:00:00
# Downloading lightning-2.4.0-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 29.3 MB/s eta 0:00:00
# Downloading tensordict-0.5.0-cp310-cp310-manylinux1_x86_64.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.1/336.1 kB 15.5 MB/s eta 0:00:00
# Downloading torchrl-0.5.0-cp310-cp310-manylinux1_x86_64.whl (987 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.0/988.0 kB 31.9 MB/s eta 0:00:00
# Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.5 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.1 MB/s eta 0:00:00
# Downloading pyrootutils-1.0.4-py3-none-any.whl (5.8 kB)
# Downloading robust_downloader-0.0.2-py3-none-any.whl (15 kB)
# Downloading wandb-0.17.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 79.8 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 12.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.6-py3-none-any.whl (26 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 19.8 MB/s eta 0:00:00
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 2.5 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.2 MB/s eta 0:00:00
# Downloading torchmetrics-1.4.1-py3-none-any.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.2/866.2 kB 32.8 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.5 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 31.6 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.6 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=1e4805a3daabcf5ab658625ba8d422ce789827a8a1c165ad8a4d369cc115b480
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, triton, smmap, setproctitle, sentry-sdk, python-dotenv, orjson, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, docker-pycreds, colorlog, robust-downloader, pyrootutils, nvidia-cusparse-cu12, nvidia-cudnn-cu12, hydra-core, gitdb, nvidia-cusolver-cu12, hydra-colorlog, gitpython, wandb, torch, torchmetrics, tensordict, torchrl, pytorch-lightning, lightning, rl4co
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.1
#     Uninstalling triton-2.3.1:
#       Successfully uninstalled triton-2.3.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1+cu121
#     Uninstalling torch-2.3.1+cu121:
#       Successfully uninstalled torch-2.3.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.1+cu121 requires torch==2.3.1, but you have torch 2.4.0 which is incompatible.
# torchvision 0.18.1+cu121 requires torch==2.3.1, but you have torch 2.4.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 colorlog-6.8.2 docker-pycreds-0.4.0 gitdb-4.0.11 gitpython-3.1.43 hydra-colorlog-1.2.0 hydra-core-1.3.2 lightning-2.4.0 lightning-utilities-0.11.6 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 orjson-3.10.7 pyrootutils-1.0.4 python-dotenv-1.0.1 pytorch-lightning-2.4.0 rl4co-0.4.0 robust-downloader-0.0.2 sentry-sdk-2.13.0 setproctitle-1.3.3 smmap-5.0.1 tensordict-0.5.0 torch-2.4.0 torchmetrics-1.4.1 torchrl-0.5.0 triton-3.0.0 wandb-0.17.7

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

import torch

from rl4co.envs import TSPEnv
from rl4co.models import AttentionModelPolicy, REINFORCE
from rl4co.utils.trainer import RL4COTrainer

# %% [markdown]
# ### Environment, Policy and Model
#
# Full documentation of:
#
# - Base environment class [here](https://rl4co.readthedocs.io/en/latest/_content/api/envs/base.html)
# - Base policy class [here](https://rl4co.readthedocs.io/en/latest/_content/api/models/base.html)
# - Base model class [here](https://rl4co.readthedocs.io/en/latest/_content/api/algos/base.html)

# %%
# RL4CO env based on TorchRL
env = TSPEnv(generator_params={'num_loc': 50})

# Policy: neural network, in this case with encoder-decoder architecture
policy = AttentionModelPolicy(env_name=env.name,
                              embed_dim=128,
                              num_encoder_layers=3,
                              num_heads=8,
                            )

# RL Model: REINFORCE and greedy rollout baseline
model = REINFORCE(env,
                    policy,
                    baseline="rollout",
                    batch_size=512,
                    train_data_size=100_000,
                    val_data_size=10_000,
                    optimizer_kwargs={"lr": 1e-4},
                    )
# Out:
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/utilities/parsing.py:208: Attribute 'env' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['env'])`.
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/utilities/parsing.py:208: Attribute 'policy' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['policy'])`.

# %% [markdown]
# ### Test greedy rollout with untrained model and plot

# %%
# Greedy rollouts over untrained policy
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
td_init = env.reset(batch_size=[3]).to(device)
policy = policy.to(device)
out = policy(td_init.clone(), phase="test", decode_type="greedy", return_actions=True)
actions_untrained = out['actions'].cpu().detach()
rewards_untrained = out['reward'].cpu().detach()

for i in range(3):
    print(f"Problem {i+1} | Cost: {-rewards_untrained[i]:.3f}")
    env.render(td_init[i], actions_untrained[i])
# Out:
# Problem 1 | Cost: 9.266
# Problem 2 | Cost: 10.459
# Problem 3 | Cost: 9.643

# %% [markdown]
# ### Trainer
#
# The RL4CO trainer is a wrapper around PyTorch Lightning's `Trainer` class which adds some functionality and more efficient defaults

# %%
trainer = RL4COTrainer(
    max_epochs=3,
    accelerator="gpu",
    devices=1,
    logger=None,
)
# Out:
# INFO: Using 16bit Automatic Mixed Precision (AMP)
# INFO:lightning.pytorch.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %% [markdown]
# ### Fit the model

# %%
trainer.fit(model)
# Out:
# WARNING:rl4co.envs.common.base:val_file not set. Generating dataset instead
# WARNING:rl4co.envs.common.base:test_file not set. Generating dataset instead
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-45d4afebefac> in <cell line: 1>()
# ----> 1 trainer.fit(model)
#
# /usr/local/lib/python3.10/dist-packages/rl4co/utils/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     144                 self.gradient_clip_val = None
#     145
# --> 146         super().fit(
#     147             model=model,
#     148             train_dataloaders=train_dataloaders,
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536         self.state.status = TrainerStatus.RUNNING
#     537         self.training = True
# --> 538         call._call_and_handle_interrupt(
#     539             self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540         )
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      45         if trainer.strategy.launcher is not None:
#      46             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47         return trainer_fn(*args, **kwargs)
#      48
#      49     except _TunerExitException:
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     572             model_connected=self.lightning_module is not None,
#     573         )
# --> 574         self._run(model, ckpt_path=ckpt_path)
#     575
#     576         assert self.state.stopped
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/trainer.py in _run(self, model, ckpt_path)
#     941         self._data_connector.prepare_data()
#     942
# --> 943         call._call_setup_hook(self)  # allow user to set up LightningModule in accelerator environment
#     944         log.debug(f"{self.__class__.__name__}: configuring model")
#     945         call._call_configure_model(self)
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py in _call_setup_hook(trainer)
#     102         _call_lightning_datamodule_hook(trainer, "setup", stage=fn)
#     103     _call_callback_hooks(trainer, "setup", stage=fn)
# --> 104     _call_lightning_module_hook(trainer, "setup", stage=fn)
#     105
#     106     trainer.strategy.barrier("post_setup")
#
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/trainer/call.py in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     165
#     166     with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 167         output = fn(*args, **kwargs)
#     168
#     169     # restore current_fx when nested context
#
# /usr/local/lib/python3.10/dist-packages/rl4co/models/rl/common/base.py in setup(self, stage)
#     153         self.dataloader_names = None
#     154         self.setup_loggers()
# --> 155         self.post_setup_hook()
#     156
#     157     def setup_loggers(self):
#
# /usr/local/lib/python3.10/dist-packages/rl4co/models/rl/reinforce/reinforce.py in post_setup_hook(self, stage)
#     108     def post_setup_hook(self, stage="fit"):
#     109         # Make baseline taking model itself and train_dataloader from model as input
# --> 110         self.baseline.setup(
#     111             self.policy,
#     112             self.env,
#
# /usr/local/lib/python3.10/dist-packages/rl4co/models/rl/reinforce/baselines.py in setup(self, *args, **kw)
#     115
#     116     def setup(self, *args, **kw):
# --> 117         self.baseline.setup(*args, **kw)
#     118
#     119     def eval(self, td, reward, env=None):
#
# /usr/local/lib/python3.10/dist-packages/rl4co/models/rl/reinforce/baselines.py in setup(self, *args, **kw)
#     172
#     173     def setup(self, *args, **kw):
# --> 174         self._update_policy(*args, **kw)
#     175
#     176     def _update_policy(
#
# /usr/local/lib/python3.10/dist-packages/rl4co/models/rl/reinforce/baselines.py in _update_policy(self, policy, env, batch_size, device, dataset_size, dataset)
#     185         log.info("Evaluating baseline policy on evaluation dataset")
#     186         self.bl_vals = (
# --> 187             self.rollout(self.policy, env, batch_size, device, self.dataset).cpu().numpy()
#     188         )
#     189         self.mean = self.bl_vals.mean()
#
# /usr/local/lib/python3.10/dist-packages/rl4co/models/rl/reinforce/baselines.py in rollout(self, policy, env, batch_size, device, dataset)
#     240         dl = DataLoader(dataset, batch_size=batch_size, collate_fn=dataset.collate_fn)
#     241
# --> 242         rewards = torch.cat([eval_policy(batch) for batch in dl], 0)
#     243         return rewards
#     244
#
# /usr/local/lib/python3.10/dist-packages/rl4co/models/rl/reinforce/baselines.py in <listcomp>(.0)
#     240         dl = DataLoader(dataset, batch_size=batch_size, collate_fn=dataset.collate_fn)
#     241
# --> 242         rewards = torch.cat([eval_policy(batch) for batch in dl], 0)
#     243         return rewards
#     244
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     671     def _next_data(self):
#     672         index = self._next_index()  # may raise StopIteration
# --> 673         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674         if self._pin_memory:
#     675             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
# ---> 55         return self.collate_fn(data)
#
# /usr/local/lib/python3.10/dist-packages/rl4co/data/dataset.py in collate_fn(batch)
#      35     def collate_fn(batch: Union[dict, TensorDict]):
#      36         """Collate function compatible with TensorDicts that reassembles a list of dicts."""
# ---> 37         return TensorDict(
#      38             {key: torch.stack([b[key] for b in batch]) for key in batch[0].keys()},
#      39             batch_size=torch.Size([len(batch)]),
#
# /usr/local/lib/python3.10/dist-packages/tensordict/_td.py in __init__(self, source, batch_size, device, names, non_blocking, lock, **kwargs)
#     238     ) -> None:
#     239         if (source is not None) and kwargs:
# --> 240             raise ValueError(
#     241                 "Either a dictionary or a sequence of kwargs must be provided, not both."
#     242             )
#
# ValueError: Either a dictionary or a sequence of kwargs must be provided, not both.

# %% [markdown]
# ### Testing

# %%
# Greedy rollouts over trained model (same states as previous plot)
policy = model.policy.to(device)
out = policy(td_init.clone(), phase="test", decode_type="greedy", return_actions=True)
actions_trained = out['actions'].cpu().detach()

# Plotting
import matplotlib.pyplot as plt
for i, td in enumerate(td_init):
    fig, axs = plt.subplots(1,2, figsize=(11,5))
    env.render(td, actions_untrained[i], ax=axs[0])
    env.render(td, actions_trained[i], ax=axs[1])
    axs[0].set_title(f"Untrained | Cost = {-rewards_untrained[i].item():.3f}")
    axs[1].set_title(r"Trained $\pi_\theta$" + f"| Cost = {-out['reward'][i].item():.3f}")

# %% [markdown]
# We can see that even after just 3 epochs, our trained AM is able to find much better solutions than the random policy! 🎉

# %%
# Optionally, save the checkpoint for later use (e.g. in tutorials/4-search-methods.ipynb)
trainer.save_checkpoint("tsp-quickstart.ckpt")
